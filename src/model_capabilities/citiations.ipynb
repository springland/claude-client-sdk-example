# %% [markdown]
# an example to show how  citations work
#
# citation detail is returned

# %%
import base64


from util.claude_client import get_claude_client_and_default_model
client , llm_model = get_claude_client_and_default_model('claude' )


with open('cdc_84800_DS1.pdf', 'rb') as f:
    pdf_base64 = base64.b64encode(f.read()).decode("utf-8")



message = client.messages.create(
    model = llm_model,
    max_tokens= 4096,
    messages= [
        {
            'role' : 'user',
            'content': [
                {
                  'type' :'document',
                    "source": {
                        "type": "base64",
                        "media_type": "application/pdf",
                        "data": pdf_base64,
                    },
                    "citations": {"enabled": True},
                    "title": "cdc_84800_DS1.pdf",
                },
                {
                    'type' :'text',
                    'text' : 'What is CDC requirement on reporting travelers from China with specific symptoms during COVID-19? ',
                }


            ]
        }
    ]
)

print( message.model_dump_json(indent=4) )
# Out:
# llm profile name : claude , model : claude-haiku-4-5-20251001
# {
#     "id": "msg_011CfSE48vZSLGBgSxBB7oak",
#     "container": null,
#     "content": [
#         {
#             "citations": [
#                 {
#                     "cited_text": "CDC reminds air carriers of the requirement under Title 42 C\r\nof Federal Regulations section 71.21 to report ill travelers to CDC who have certain signs and symptoms during flight, \r\nall deaths onboard, prior to arrival in the United States. ",
#                     "document_index": 0,
#                     "document_title": "cdc_84800_DS1.pdf",
#                     "end_page_number": 2,
#                     "file_id": null,
#                     "start_page_number": 1,
#                     "type": "page_location"
#                 }
#             ],
#             "text": "The CDC reminds air carriers of the requirement under Title 42 of Federal Regulations section 71.21 to report ill travelers to CDC who have certain signs and symptoms during flight, all deaths onboard, prior to arrival in the United States.",
#             "type": "text"
#         },
#         {
#             "citations": null,
#             "text": "\n\nSpecifically, ",
#             "type": "text"
#         },
#         {
#             "citations": [
#                 {
#                     "cited_text": "Report travelers with\r\nfever (person feels warm to the touch, gives a history of feeling feverish, or has an actual measured\r\ntemperature of 100.4°F [38° C] or higher) that has persisted for more than 48 hours\r\nOR\r\nfever AND one of the following:\r\npersistent cough\r\ndifficulty breathing\r\n! \"",
#                     "document_index": 0,
#                     "document_title": "cdc_84800_DS1.pdf",
#                     "end_page_number": 2,
#                     "file_id": null,
#                     "start_page_number": 1,
#                     "type": "page_location"
#                 }
#             ],
#             "text": "airlines should report travelers with fever (person feels warm to the touch, gives a history of feeling feverish, or has an actual measured temperature of 100.4°F [38° C] or higher) that has persisted for more than 48 hours OR fever AND one of the following: persistent cough or difficulty breathing",
#             "type": "text"
#         },
#         {
#             "citations": null,
#             "text": ", as well as ",
#             "type": "text"
#         },
#         {
#             "citations": [
#                 {
#                     "cited_text": "appears obviously unwell\r\nReport, as soon as possible before arrival, by one of the methods described in the Guidance for Air Travel Indust\r\nReporting of Onboard Death or Illnesses to CDC.\r\n",
#                     "document_index": 0,
#                     "document_title": "cdc_84800_DS1.pdf",
#                     "end_page_number": 3,
#                     "file_id": null,
#                     "start_page_number": 2,
#                     "type": "page_location"
#                 }
#             ],
#             "text": "those who appear obviously unwell, as soon as possible before arrival, by one of the methods described in the Guidance for Air Travel Industry Reporting of Onboard Death or Illnesses to CDC.",
#             "type": "text"
#         }
#     ],
#     "model": "claude-haiku-4-5-20251001",
#     "role": "assistant",
#     "stop_details": null,
#     "stop_reason": "end_turn",
#     "stop_sequence": null,
#     "type": "message",
#     "usage": {
#         "cache_creation": {
#             "ephemeral_1h_input_tokens": 0,
#             "ephemeral_5m_input_tokens": 0
#         },
#         "cache_creation_input_tokens": 0,
#         "cache_read_input_tokens": 0,
#         "inference_geo": "not_available",
#         "input_tokens": 7042,
#         "output_tokens": 222,
#         "output_tokens_details": null,
#         "server_tool_use": null,
#         "service_tier": "standard"
#     },
#     "diagnostics": null
# }
